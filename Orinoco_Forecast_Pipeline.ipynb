# %% [markdown]
# # Reproducción de Resultados: Proyecto Orinoco Forecast
# Este cuaderno automatiza la reproducción exacta de los modelos **LSTM** y **Transformer** presentados en el trabajo de grado.
#
# **Requisito previo:** Asegúrese de estar utilizando un entorno con GPU (Entorno -> Cambiar tipo de entorno -> T4 GPU).

# %% [markdown]
# ## 1. Clonar el Repositorio

# %%
# !git clone https://github.com/iadev0721/orinoco-forecast.git

# %% [markdown]
# ## 2. Entrar al Directorio del Proyecto

# %%
# %cd orinoco-forecast

# %% [markdown]
# ## 3. Instalar Dependencias

# %%
# !pip install -r requirements.txt

# %% [markdown]
# ## 4. Descargar Dataset desde Google Drive
# Se descarga el dataset preprocesado para cumplir con las reglas de reproducibilidad sin versionar datos en Git.

# %%
# !pip install -qU gdown
# !gdown --folder https://drive.google.com/drive/folders/18UMol_4_zto7Wuh0TPwPKjMiP2znd5L5 -O downloaded_data
# !mkdir -p data/processed data/raw
# !find downloaded_data -name "dataset_orinoco_features.csv" -exec mv {} data/processed/ \;
# !echo "Dataset posicionado correctamente en data/processed/"

# %% [markdown]
# ## 5. Entrenamiento: Modelo LSTM (M5)
# Ejecuta el ensamble LSTM con validación estricta y corrección de sesgo residual.

# %%
# !python lstm.py

# %% [markdown]
# ## 6. Entrenamiento: Modelo Transformer (M7)
# Ejecuta el ensamble Transformer basado en atención.

# %%
# !python transformer.py
