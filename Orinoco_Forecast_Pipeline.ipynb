# %% [markdown]
# # Orinoco Forecast - Pipeline de Reproduccion
# **Requisito:** GPU activada (Entorno -> Cambiar tipo de entorno -> T4 GPU)

# %%
# !git clone https://github.com/iadev0721/orinoco-forecast.git

# %%
# %cd orinoco-forecast

# %%
# !pip install -r requirements.txt

# %%
import gdown, os
os.makedirs('data/processed', exist_ok=True)
# Descarga directa por ID de archivo (mas fiable que download_folder)
gdown.download(id='1YqipnXoXiImQAfIX8y1NGBPh5nCpPps0', output='data/processed/dataset_orinoco_features.csv', quiet=False)

# %%
# !python lstm.py

# %%
# !python transformer.py
