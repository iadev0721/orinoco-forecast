# %% [markdown]
# # 🌊 Orinoco Forecast - Pipeline de Reproducción
# **⚠️ Requisito importante:** Es necesario habilitar la aceleración por hardware para el entrenamiento de los modelos.
#
# Para ello, diríjase al menú superior y seleccione:
# **Entorno de ejecución** > **Cambiar tipo de entorno de ejecución** > Seleccione **T4 GPU** como acelerador.

# %%
# !git clone https://github.com/iadev0721/orinoco-forecast.git

# %%
# %cd orinoco-forecast

# %%
# !pip install -q -r requirements_colab.txt

# %%
# !python lstm.py

# %%
# !python transformer.py
