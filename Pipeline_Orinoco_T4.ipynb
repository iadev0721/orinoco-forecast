# %% [markdown]
# # Orinoco Forecast - Pipeline de Reproduccion
# **Requisito:** entrar a la opcion "entorno de ejecucion" y luego "cambiar tipo de entorno de ejecucion" y que ahi seleccione la T4 GPU

# %%
# !git clone https://github.com/iadev0721/orinoco-forecast.git

# %%
# %cd orinoco-forecast

# %%
# !pip install -q -r requirements_colab.txt

# %%
# !python lstm.py

# %%
# !python transformer.py
